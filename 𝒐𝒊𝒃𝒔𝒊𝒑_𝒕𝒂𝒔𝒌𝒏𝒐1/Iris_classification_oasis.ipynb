# %%
#task1
#OasisInfobyte
#AruneshDubey
import os
import pandas as pd
import matplotlib.pyplot as mt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
data = pd.read_csv('iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data=data.drop(columns=['Id'])
data.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
counts=data['Species'].value_counts()
counts
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
data['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
data['PetalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
data['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
colors=['blue','yellow','red']
Species=['Iris-setosa','Iris-virginica','Iris-versicolor']

# %%
for i in range(3):
    x=data[data['Species']==Species[i]]
    mt.scatter(x['SepalLengthCm'],x['SepalWidthCm'],c=colors[i],label=Species[i])
    mt.xlabel('SepalLengthCm')
    mt.ylabel('SepalWidthCm')
    mt.legend()

# %%
for i in range(3):
    x=data[data['Species']==Species[i]]
    mt.scatter(x['PetalLengthCm'],x['PetalWidthCm'],c=colors[i],label=Species[i])
    mt.xlabel('PetalLengthCm')
    mt.ylabel('PetalWidthCm')
    mt.legend()

# %%
for i in range(3):
    x=data[data['Species']==Species[i]]
    mt.scatter(x['SepalLengthCm'],x['PetalWidthCm'],c=colors[i],label=Species[i])
    mt.xlabel('PetalLengthCm')
    mt.ylabel('PetalWidthCm')
    mt.legend()

# %%
for i in range(3):
    x=data[data['Species']==Species[i]]
    mt.scatter(x['PetalLengthCm'],x['SepalWidthCm'],c=colors[i],label=Species[i])
    mt.xlabel('PetalLengthCm')
    mt.ylabel('PetalWidthCm')
    mt.legend()

# %%
mt.pie(counts,labels=Species)
mt.title("Count of Species",fontsize=20)
mt.show()

# %%
mt.subplots(figsize=(7,7))
sb.scatterplot(x="PetalLengthCm",y="PetalWidthCm",data=data,hue="Species")
mt.show()

# %%
mt.subplots(figsize=(7,7))
sb.scatterplot(x="SepalLengthCm",y="SepalWidthCm",data=data,hue="Species")
mt.show()

# %%
plot=sb.pairplot(data,hue="Species",diag_kind="hist")
plot.fig.suptitle("Relation with each other",y=1.1,fontsize=20)
mt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(["Species"],axis=1)
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
Y = data["Species"]
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
model = LogisticRegression(max_iter=1000)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=1)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
predictions = model.predict(x_test)
print(classification_report(y_test,predictions))
print("Confusion Matrix\n",confusion_matrix(y_test,predictions))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      0.94      0.97        18
#  Iris-virginica       0.93      1.00      0.96        13
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# Confusion Matrix
#  [[14  0  0]
#  [ 0 17  1]
#  [ 0  0 13]]

# %%
print(accuracy_score(y_test,predictions))
# Out:
# 0.9777777777777777
